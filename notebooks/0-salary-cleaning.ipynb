# %% [markdown]
# ## Research Questions
#
# ### Economics questions
#
# * How are the employees of the City of Chicago paid by job title relative to other areas with that job in the US?
#   * We will need data at the level of the City of Chicago and at a national level, perhaps that supplied by the Bureau of Labor Statistics.
#
#
# ### Gender-related questions
#
# If the dataset we start with doesn't have an indication of gender, how will we estimate it?
#
# Could we infer gender from first name?
#
# * How are men with the same job titles in the same departments paid relative to women in the City of Chicago?
#
# * Do women do different jobs than men in the City?
#
# * Are women or men in management roles proportional to the gender distribution of the department?
#   * How do we define which roles are management roles?
#
# Considerations:
#
# * How would time spent in the department, position, or career affect compensation?
#
# ### Compensation Questions
#
# * Do people with common names get paid differently from people with uncommon names?
#
#
# ### Safety-related questions
#
# * What are the safest jobs in the City?
#   * How do we define 'safe'? Where can we get data?
#
#
# ## Informational Views
#
# * Show employees by department.
#   * Enrichment idea: Merge in a description of department data so that we have a better idea of where people work.
# * Show employees by job title.
# * Show the salary of an individual by first or last name.

# %% [markdown]
# ## We'll start with the "Name, Salary, Title" dataset from the Chicago Data Portal
#
# https://data.cityofchicago.org/Administration-Finance/Current-Employee-Names-Salaries-and-Position-Title/xzkq-xp2w
#
# > This dataset is a listing of all current City of Chicago employees, complete with full names, departments, positions, employment status (part-time or full-time), frequency of hourly employee –where applicable—and annual salaries or hourly rate. For hourly employees, the City is providing the hourly rate and frequency of hourly employees (40, 35, 20 and 10) to allow dataset users to estimate annual wages for hourly employees. Please note that annual wages will vary by employee, depending on number of hours worked and seasonal status. For information on the positions and related salaries detailed in the annual budgets, see https://www.cityofchicago.org/city/en/depts/obm.html
#
#
# ## Data Cleansing - Getting to Tidy Data
#
# We'll need to explore this dataset to see what it offers. We can tell from the description that, at a minimum, we're going to need to do some work "to estimate annual wages for hourly employees". We want to be able to make comparisons of salary between groups for either of our research questions.

# %%
import seaborn as sns
sns.set()

import pandas as pd

# %%
# Enable the notebook to automatically reload. 
# This makes it possible to move your code to the src folder and to use libraries you
# pip install along the way.

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %matplotlib inline

# %%
data = pd.read_csv('../data/raw/chicago-salaries.csv')

# %%
data.head()
# Out:
#                   Name                              Job Titles  \
# 0    AARON,  JEFFERY M                                SERGEANT
# 1      AARON,  KARINA   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2  AARON,  KIMBERLEI R                CHIEF CONTRACT EXPEDITER
# 3  ABAD JR,  VICENTE M                       CIVIL ENGINEER IV
# 4    ABASCAL,  REECE E             TRAFFIC CONTROL AIDE-HOURLY
#
#          Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 0            POLICE                 F           Salary            NaN
# 1            POLICE                 F           Salary            NaN
# 2  GENERAL SERVICES                 F           Salary            NaN
# 3       WATER MGMNT                 F           Salary            NaN
# 4              OEMC                 P           Hourly           20.0
#
#    Annual Salary  Hourly Rate
# 0       101442.0          NaN
# 1        94122.0          NaN
# 2       101592.0          NaN
# 3       110064.0          NaN
# 4            NaN        19.86

# %%
data.describe(include='all')
# Out:
#                      Name      Job Titles Department Full or Part-Time  \
# count               33183           33183      33183             33183
# unique              32880            1111         35                 2
# top     KELLY,  MICHAEL J  POLICE OFFICER     POLICE                 F
# freq                    4            9520      13414             31090
# mean                  NaN             NaN        NaN               NaN
# std                   NaN             NaN        NaN               NaN
# min                   NaN             NaN        NaN               NaN
# 25%                   NaN             NaN        NaN               NaN
# 50%                   NaN             NaN        NaN               NaN
# 75%                   NaN             NaN        NaN               NaN
# max                   NaN             NaN        NaN               NaN
#
#        Salary or Hourly  Typical Hours  Annual Salary  Hourly Rate
# count             33183    8022.000000   25161.000000  8022.000000
# unique                2            NaN            NaN          NaN
# top              Salary            NaN            NaN          NaN
# freq              25161            NaN            NaN          NaN
# mean                NaN      34.507604   86786.999790    32.788558
# std                 NaN       9.252077   21041.354602    12.112573
# min                 NaN      10.000000    7200.000000     2.650000
# 25%                 NaN      20.000000   76266.000000    21.200000
# 50%                 NaN      40.000000   90024.000000    35.600000
# 75%                 NaN      40.000000   96060.000000    40.200000
# max                 NaN      40.000000  300000.000000   109.000000

# %% [markdown]
# ## Tidy vs. Messy Data
#
# When people talk about "cleaning" data, they really mean structuring the data in such a way as to make initial exploration and analysis easier. Instead of having to constantly re-invent the wheel and tailor your analysis workflow to the shape of every dataset, you reshape the data to fit a standard analysis workflow. Seaborn's plotting functions, for example, are optimized to work with [data in tidy format](https://seaborn.pydata.org/introduction.html#intro-tidy-data).
#
# We want our data set to be "tidy".
#
# Hadley Wickham coined the term [Tidy Data](https://vita.had.co.nz/papers/tidy-data.pdf) to describe data that is clean and ready for analysis.
#
# * Each variable is a column. A variable contains all values that measure the same underlying attribute (like height, temperature, duration) across units.
# * Each observation is a row. An observation contains all values measured on the same unit (like a person, or a day, or a race) across attributes.
# * Each type of observational unit is a table
#
# This is essentially [Codd's 3rd Normal Form](https://en.wikipedia.org/wiki/Third_normal_form) for a single dataset.
#
# Messy data is any other arrangement of the data.
#
# The five most common problems with messy datasets are:
#
# * Column headers are values, not variable names.
#   * [Example](http://python-graph-gallery.com/boxplot/)
#   * Solution: [`melt`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.melt.html) the data from wide to long format.
# * Multiple variables are stored in one column. This can happen in either the column name or the column values.
#   * Examples:
#     * `{'name': 'Shumway, Gordon'}`
#     * `[{'sizeChicago': 42, 'sizeNewYork': 8}]`
#   * Solution: Split the data so that each variable is a column.
#     * `{'first_name': 'Gordon', 'last_name': 'Shumway'}`
#     * `[{'size': 42, 'location': 'Chicago'}, {'size': 8, 'location': 'New York'}`
# * Variables are stored in both rows and columns.
# * Multiple types of observational units are stored in the same table.
#   * Solution: Split the data into multiple tables; tidy those tables. Potentially merge them back into a single table.
# * A single observational unit is stored in multiple tables.
#   * Solution: Merge the data into a single table.
#
#
# ## Data Cleansing TODO List
#
#
# **Rename columns to allow attribute access in Pandas.**
#
# Pandas provides the ability to access columns directly with [attribute access](http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#attribute-access) indexing. For example, we can write `data.Department`, including auto-complete, instead of `data['Department']`. This is really a matter of convenience for us to work with data in Pandas more easily, but it's an easy win to take unless there's a good reason why we can't rename a column.
#
# This only works if our attributes follow these rules:
#
# * You can use this access only if the index element is a [valid Python identifier](https://docs.python.org/3/reference/lexical_analysis.html#identifiers), e.g. s.1 is not allowed.
# * The attribute will not be available if it conflicts with an existing method name, e.g. `s.min` is not allowed.
# * Similarly, the attribute will not be available if it conflicts with any of the following list: `index`, `major_axis`, `minor_axis`, `items`.
# * In any of these cases, standard indexing will still work, e.g. `s['1']`, `s['min']`, and `s['index']` will access the corresponding element or column.
#
# We can rename each of the columns to a valid Python identifier to make our life easier.
#
#
# **Split first name, last name, and middle initial.**
#
# Tidy data means the data in each column can't be further split. Doing this with name may not seem to have any immediate benefits; treat it as a cheap speculative bet at this point.
#
#
# **Handle NaN values for "Full or Part-Time" and "Salary or Hourly" observations.**
#
# This is an example of the "Multiple types of observational units are stored in the same table" type of mess.
#
# We can see from the `head` preview above that there are `NaN` values. Some of the columns are only defined for Full-Time employees, and some only make sense for Part-Time. Full-time staff typically do different types of work than part-time. Some of part-time work is seasonal. Part-time staff are compensated differently. We'll need to do some work to compare the two types of employees.
#
# There are four possible classes of the dataset:
#
# <table>
#     <tr><td>PT Hourly</td><td>PT Salary</td></tr>
#     <tr><td>FT Hourly</td><td>FT Salary</td></tr>
# </table>
#
# Going back to our definition of tidy data, we want each row to contain all values measured on the same person across attributes. We want to compare groups of rows, not groups of columns, in our analysis. This means each column should have a meaningful value for every row.
#
# The attributes which vary by class are "Typical Hours", "Annual Salary", and "Hourly Rate".
#
# This means we need to ensure that every person has:
#
# * `typical_hours` as 40 for full-time staff
# * an `hourly_rate`, which is a function of salary / 52 / 40 for staff paid by salary.
# * an `annualized_income`: We can get an approximation for this for hourly staff as a function of Typical Hours, Hourly Rate, and 52 weeks in a year.
#
# **Investigate duplicates.**
#
# We have 33183 entries, but only 32880 unique names. It seems there are ~300 duplicated names. This might be normal...some names are more common than others. We'll want to investigate to see if there's anything we need to do about this.

# %% [markdown]
# ### Rename columns to allow attribute access in Pandas

# %%
# names = {'Name': 'name', 
#          'Job Titles': 'job_title',
#          'Department': ...
#         }

# data = data.rename(index=str, columns=names)

# OR...

# rename can also take a function to run on each of the columns, e.g.
# df.rename(str.lower, axis='columns')

# you could define a function that will replace whitespace and dashes with underscores,
# then pass that function to rename.
import re

def to_snake(s):
    return re.sub("([\s]+|[-]+)", "_", s).lower().lstrip("_")

# %%
to_snake("Job Title")
# Out:
# 'job_title'

# %%
to_snake("Description")
# Out:
# 'description'

# %%
to_snake("Full or Part-Time")
# Out:
# 'full_or_part_time'

# %%
data = data.rename(to_snake, axis='columns')

# %% [markdown]
# ### Split first name, last name, middle initial

# %%
no_middle_initial = data.iloc[1]['name']

# %%
no_middle_initial
# Out:
# 'AARON,  KARINA '

# %%
middle_initial = data.iloc[0]['name']

# %%
middle_initial
# Out:
# 'AARON,  JEFFERY M'

# %%
suffix = data.iloc[23]['name']

# %%
suffix
# Out:
# 'ABERCROMBIE IV,  EARL S'

# %%
suffix.split(' ')
# Out:
# ['ABERCROMBIE', 'IV,', '', 'EARL', 'S']

# %%
middle_initial.split(' ')
# Out:
# ['AARON,', '', 'JEFFERY', 'M']

# %%
no_middle_initial.split(' ')
# Out:
# ['AARON,', '', 'KARINA', '']

# %%
suffix.split(',')
# Out:
# ['ABERCROMBIE IV', '  EARL S']

# %%
no_middle_initial.split(',')
# Out:
# ['AARON', '  KARINA ']

# %%
names = [no_middle_initial, middle_initial, suffix]

# %%
def last_name(s):
    return s.split(',')[0]

# %%
data = data.assign(last_name=[last_name(n) for n in data.name])

# %%
data.columns
# Out:
# Index(['name', 'job_titles', 'department', 'full_or_part_time',
#        'salary_or_hourly', 'typical_hours', 'annual_salary', 'hourly_rate',
#        'last_name'],
#       dtype='object')

# %%
data.head()
# Out:
#                   name                              job_titles  \
# 0    AARON,  JEFFERY M                                SERGEANT
# 1      AARON,  KARINA   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2  AARON,  KIMBERLEI R                CHIEF CONTRACT EXPEDITER
# 3  ABAD JR,  VICENTE M                       CIVIL ENGINEER IV
# 4    ABASCAL,  REECE E             TRAFFIC CONTROL AIDE-HOURLY
#
#          department full_or_part_time salary_or_hourly  typical_hours  \
# 0            POLICE                 F           Salary            NaN
# 1            POLICE                 F           Salary            NaN
# 2  GENERAL SERVICES                 F           Salary            NaN
# 3       WATER MGMNT                 F           Salary            NaN
# 4              OEMC                 P           Hourly           20.0
#
#    annual_salary  hourly_rate last_name
# 0       101442.0          NaN     AARON
# 1        94122.0          NaN     AARON
# 2       101592.0          NaN     AARON
# 3       110064.0          NaN   ABAD JR
# 4            NaN        19.86   ABASCAL

# %%
temp = middle_initial.split(',')[1].strip()
temp.split(' ')
# Out:
# ['JEFFERY', 'M']

# %%
temp = no_middle_initial.split(',')[1].strip()
temp.split(' ')
# Out:
# ['KARINA']

# %%
def first_name(s):
    first_names = s.split(',')[1].strip()
    return first_names.split(' ')[0]

# %%
first_name(no_middle_initial)
# Out:
# 'KARINA'

# %%
first_name(middle_initial)
# Out:
# 'JEFFERY'

# %%
first_name(suffix)
# Out:
# 'EARL'

# %%
data = data.assign(first_name=[first_name(n) for n in data.name])

# %%
def middle_initial(s):
# Out:
#                   name                              job_titles  \
# 0    AARON,  JEFFERY M                                SERGEANT
# 1      AARON,  KARINA   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2  AARON,  KIMBERLEI R                CHIEF CONTRACT EXPEDITER
# 3  ABAD JR,  VICENTE M                       CIVIL ENGINEER IV
# 4    ABASCAL,  REECE E             TRAFFIC CONTROL AIDE-HOURLY
#
#          department full_or_part_time salary_or_hourly  typical_hours  \
# 0            POLICE                 F           Salary            NaN
# 1            POLICE                 F           Salary            NaN
# 2  GENERAL SERVICES                 F           Salary            NaN
# 3       WATER MGMNT                 F           Salary            NaN
# 4              OEMC                 P           Hourly           20.0
#
#    annual_salary  hourly_rate last_name first_name
# 0       101442.0          NaN     AARON    JEFFERY
# 1        94122.0          NaN     AARON     KARINA
# 2       101592.0          NaN     AARON  KIMBERLEI
# 3       110064.0          NaN   ABAD JR    VICENTE
# 4            NaN        19.86   ABASCAL      REECE

# %%
def middle_name(s):
    first_names = s.split(',')[1].strip()
    maybe_first_names = first_names.split(' ')
    if len(maybe_first_names) > 1:
        return maybe_first_names[1]
    return ' '

# %%
middle_name(middle_initial)
# Out:
# 'M'

# %%
middle_name(no_middle_initial)
# Out:
# ' '

# %%
middle_name(suffix)
# Out:
# 'S'

# %%
data = data.assign(middle_name=[middle_name(n) for n in data.name])

# %%
data.head()
# Out:
#                   name                              job_titles  \
# 0    AARON,  JEFFERY M                                SERGEANT
# 1      AARON,  KARINA   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2  AARON,  KIMBERLEI R                CHIEF CONTRACT EXPEDITER
# 3  ABAD JR,  VICENTE M                       CIVIL ENGINEER IV
# 4    ABASCAL,  REECE E             TRAFFIC CONTROL AIDE-HOURLY
#
#          department full_or_part_time salary_or_hourly  typical_hours  \
# 0            POLICE                 F           Salary            NaN
# 1            POLICE                 F           Salary            NaN
# 2  GENERAL SERVICES                 F           Salary            NaN
# 3       WATER MGMNT                 F           Salary            NaN
# 4              OEMC                 P           Hourly           20.0
#
#    annual_salary  hourly_rate last_name first_name middle_name
# 0       101442.0          NaN     AARON    JEFFERY           M
# 1        94122.0          NaN     AARON     KARINA
# 2       101592.0          NaN     AARON  KIMBERLEI           R
# 3       110064.0          NaN   ABAD JR    VICENTE           M
# 4            NaN        19.86   ABASCAL      REECE           E

# %%
def hours(row):
    h = row['typical_hours']
    return 40.0 if pd.isna(h) else h


new_hours = pd.DataFrame({'typical_hours': [hours(row) for _, row in data.iterrows()]})

# %%
new_hours.describe()
# Out:
#        typical_hours
# count   33183.000000
# mean       38.672212
# std         5.120740
# min        10.000000
# 25%        40.000000
# 50%        40.000000
# 75%        40.000000
# max        40.000000

# %%
data.update(new_hours)

# %%
data.head()
# Out:
#                   name                              job_titles  \
# 0    AARON,  JEFFERY M                                SERGEANT
# 1      AARON,  KARINA   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2  AARON,  KIMBERLEI R                CHIEF CONTRACT EXPEDITER
# 3  ABAD JR,  VICENTE M                       CIVIL ENGINEER IV
# 4    ABASCAL,  REECE E             TRAFFIC CONTROL AIDE-HOURLY
#
#          department full_or_part_time salary_or_hourly  typical_hours  \
# 0            POLICE                 F           Salary           40.0
# 1            POLICE                 F           Salary           40.0
# 2  GENERAL SERVICES                 F           Salary           40.0
# 3       WATER MGMNT                 F           Salary           40.0
# 4              OEMC                 P           Hourly           20.0
#
#    annual_salary  hourly_rate last_name first_name middle_name
# 0       101442.0          NaN     AARON    JEFFERY           M
# 1        94122.0          NaN     AARON     KARINA
# 2       101592.0          NaN     AARON  KIMBERLEI           R
# 3       110064.0          NaN   ABAD JR    VICENTE           M
# 4            NaN        19.86   ABASCAL      REECE           E

# %% [markdown]
# Get every employee that doesn't have an hourly rate.
# Do any of them not have an annual salary?

# %%
data[data.hourly_rate.isna()].annual_salary.isna().value_counts()
# Out:
# False    25161
# Name: annual_salary, dtype: int64

# %%
def rate(row):
    r = row['hourly_rate']
    if pd.isna(r):
        return row['annual_salary'] / (52.0 * 40.0)
    return r

# %%
new_rate = pd.DataFrame({'hourly_rate': [rate(row) for _, row in data.iterrows()]})

# %%
data.update(new_rate)

# %%
data.head()
# Out:
#                   name                              job_titles  \
# 0    AARON,  JEFFERY M                                SERGEANT
# 1      AARON,  KARINA   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2  AARON,  KIMBERLEI R                CHIEF CONTRACT EXPEDITER
# 3  ABAD JR,  VICENTE M                       CIVIL ENGINEER IV
# 4    ABASCAL,  REECE E             TRAFFIC CONTROL AIDE-HOURLY
#
#          department full_or_part_time salary_or_hourly  typical_hours  \
# 0            POLICE                 F           Salary           40.0
# 1            POLICE                 F           Salary           40.0
# 2  GENERAL SERVICES                 F           Salary           40.0
# 3       WATER MGMNT                 F           Salary           40.0
# 4              OEMC                 P           Hourly           20.0
#
#    annual_salary  hourly_rate last_name first_name middle_name
# 0       101442.0    48.770192     AARON    JEFFERY           M
# 1        94122.0    45.250962     AARON     KARINA
# 2       101592.0    48.842308     AARON  KIMBERLEI           R
# 3       110064.0    52.915385   ABAD JR    VICENTE           M
# 4            NaN    19.860000   ABASCAL      REECE           E

# %%
def salary(row):
    r = row['annual_salary']
    if pd.isna(r):
        return row['typical_hours'] * row['hourly_rate'] * 52
    return r

# %%
income = [salary(row) for _, row in data.iterrows()]

# %%
data = data.assign(annualized_income=income)

# %%
data.head()
# Out:
#                   name                              job_titles  \
# 0    AARON,  JEFFERY M                                SERGEANT
# 1      AARON,  KARINA   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2  AARON,  KIMBERLEI R                CHIEF CONTRACT EXPEDITER
# 3  ABAD JR,  VICENTE M                       CIVIL ENGINEER IV
# 4    ABASCAL,  REECE E             TRAFFIC CONTROL AIDE-HOURLY
#
#          department full_or_part_time salary_or_hourly  typical_hours  \
# 0            POLICE                 F           Salary           40.0
# 1            POLICE                 F           Salary           40.0
# 2  GENERAL SERVICES                 F           Salary           40.0
# 3       WATER MGMNT                 F           Salary           40.0
# 4              OEMC                 P           Hourly           20.0
#
#    annual_salary  hourly_rate last_name first_name middle_name  \
# 0       101442.0    48.770192     AARON    JEFFERY           M
# 1        94122.0    45.250962     AARON     KARINA
# 2       101592.0    48.842308     AARON  KIMBERLEI           R
# 3       110064.0    52.915385   ABAD JR    VICENTE           M
# 4            NaN    19.860000   ABASCAL      REECE           E
#
#    annualized_income
# 0           101442.0
# 1            94122.0
# 2           101592.0
# 3           110064.0
# 4            20654.4

# %%
data.describe()
# Out:
#        typical_hours  annual_salary   hourly_rate  annualized_income
# count   33183.000000   25161.000000  33183.000000       33183.000000
# mean       38.672212   86786.999790     39.564248       81069.414879
# std         5.120740   21041.354602     11.300300       26023.868229
# min        10.000000    7200.000000      2.650000        2756.000000
# 25%        40.000000   76266.000000     34.860577       72510.000000
# 50%        40.000000   90024.000000     41.829808       87006.000000
# 75%        40.000000   96060.000000     46.100000       95888.000000
# max        40.000000  300000.000000    144.230769      300000.000000

# %%
data[data.duplicated(['name'], keep=False)]
# Out:
#                          name                                job_titles  \
# 173             ADE,  JAMES P                            POLICE OFFICER
# 174             ADE,  JAMES P                                  SERGEANT
# 735        ANDERSON,  DAVID C                    PROJECTS ADMINISTRATOR
# 736        ANDERSON,  DAVID C                          SEWER BRICKLAYER
# 742        ANDERSON,  DONALD         FOREMAN OF WATER PIPE CONSTRUCTION
# 743        ANDERSON,  DONALD                            PROJECT MANAGER
# 788       ANDERSON,  RHONDA M           PROPERTY CUSTODIAN - AUTO POUND
# 789       ANDERSON,  RHONDA M                                  SERGEANT
# 1051      ARROYO,  FRANCISCO                               LIBRARIAN II
# 1052      ARROYO,  FRANCISCO                        WARD SUPERINTENDENT
# 1133       ATECA,  SALVADOR R                    MACHINIST (AUTOMOTIVE)
# 1134       ATECA,  SALVADOR R                        MOTOR TRUCK DRIVER
# 2148      BIANCHI,  MICHAEL J            FIRE COMMUNICATIONS OPERATOR I
# 2149      BIANCHI,  MICHAEL J         FOREMAN OF STREET LIGHT REPAIRMEN
# 2750       BRACKEN,  DANIEL J                                 CARPENTER
# 2751       BRACKEN,  DANIEL J                                 PARAMEDIC
# 3077         BROWN,  ANTHONY                      GENERAL LABORER - DSS
# 3078         BROWN,  ANTHONY                             POLICE OFFICER
# 3130           BROWN,  DIANE            PAYMENT SERVICES REPRESENTATIVE
# 3131           BROWN,  DIANE                    POOL MOTOR TRUCK DRIVER
# 3226         BROWN,  MICHAEL                             POLICE OFFICER
# 3227         BROWN,  MICHAEL                TRAFFIC CONTROL AIDE-HOURLY
# 3244        BROWN,  PATRICK J                            LIEUTENANT-EMT
# 3245        BROWN,  PATRICK J    POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 3297        BROWN,  WILLIAM R                         FIRE ENGINEER-EMT
# 3298        BROWN,  WILLIAM R  POLICE OFFICER (ASGND AS MARINE OFFICER)
# 3736       CACERES,  RICHARD                             POLICE OFFICER
# 3737       CACERES,  RICHARD                             POLICE OFFICER
# 3918     CAMPBELL,  MICHAEL P                           FIREFIGHTER-EMT
# 3919     CAMPBELL,  MICHAEL P                                  SERGEANT
# ...                       ...                                       ...
# 31298  WASHINGTON,  BARBARA A                          GARAGE ATTENDANT
# 31299  WASHINGTON,  BARBARA A                             LIBRARY CLERK
# 31310     WASHINGTON,  ERIC T                              DEPUTY CHIEF
# 31311     WASHINGTON,  ERIC T                           FIREFIGHTER-EMT
# 31412       WATSON,  WILLIAM                             POLICE OFFICER
# 31413       WATSON,  WILLIAM                       SUPVSR OF ACCOUNTING
# 31889       WILLIAMS,  ANDRE                            FIREFIGHTER-EMT
# 31890       WILLIAMS,  ANDRE                             POLICE OFFICER
# 31921      WILLIAMS,  BRENDA                         FOSTER GRANDPARENT
# 31922      WILLIAMS,  BRENDA                         HOSPITALITY WORKER
# 31940    WILLIAMS,  CLARENCE                    POOL MOTOR TRUCK DRIVER
# 31941    WILLIAMS,  CLARENCE                    POOL MOTOR TRUCK DRIVER
# 32052    WILLIAMS,  KIMBERLY          ADMINISTRATIVE ASST II - EXCLUDED
# 32053    WILLIAMS,  KIMBERLY                        ANIMAL CARE AIDE II
# 32057       WILLIAMS,  LARUE                           CONCRETE LABORER
# 32058       WILLIAMS,  LARUE                      GENERAL LABORER - DSS
# 32091     WILLIAMS,  MICHAEL                               ARCHITECT II
# 32092     WILLIAMS,  MICHAEL                           GARAGE ATTENDANT
# 32114   WILLIAMS,  PATRICIA A                SENIOR DATA ENTRY OPERATOR
# 32115   WILLIAMS,  PATRICIA A               TRAFFIC CONTROL AIDE-HOURLY
# 32127      WILLIAMS,  REGINA                           CUSTODIAL WORKER
# 32128      WILLIAMS,  REGINA                             DISTRICT CLERK
# 32258       WILSON,  EDWARD J                     FIREFIGHTER/PARAMEDIC
# 32259       WILSON,  EDWARD J                             PARAMEDIC I/C
# 32270       WILSON,  JANICE L                            POLICE OFFICER
# 32271       WILSON,  JANICE L                        SANITATION LABORER
# 32280        WILSON,  JOSHUA                             POLICE OFFICER
# 32281        WILSON,  JOSHUA                             POLICE OFFICER
# 32672     WRONOWSKI,  JAMES J        AVIATION SECURITY OFFICER - HOURLY
# 32673     WRONOWSKI,  JAMES J                               FIREFIGHTER
#
#              department full_or_part_time salary_or_hourly  typical_hours  \
# 173              POLICE                 F           Salary           40.0
# 174              POLICE                 F           Salary           40.0
# 735           BUILDINGS                 F           Salary           40.0
# 736         WATER MGMNT                 F           Hourly           40.0
# 742         WATER MGMNT                 F           Hourly           40.0
# 743            AVIATION                 F           Salary           40.0
# 788       STREETS & SAN                 F           Salary           40.0
# 789              POLICE                 F           Salary           40.0
# 1051     PUBLIC LIBRARY                 F           Salary           40.0
# 1052      STREETS & SAN                 F           Salary           40.0
# 1133   GENERAL SERVICES                 F           Hourly           40.0
# 1134           AVIATION                 F           Hourly           40.0
# 2148               OEMC                 F           Salary           40.0
# 2149         TRANSPORTN                 F           Salary           40.0
# 2750         TRANSPORTN                 F           Hourly           40.0
# 2751               FIRE                 F           Salary           40.0
# 3077      STREETS & SAN                 F           Hourly           40.0
# 3078             POLICE                 F           Salary           40.0
# 3130         CITY CLERK                 F           Salary           40.0
# 3131           AVIATION                 F           Hourly           40.0
# 3226             POLICE                 F           Salary           40.0
# 3227               OEMC                 P           Hourly           20.0
# 3244               FIRE                 F           Salary           40.0
# 3245             POLICE                 F           Salary           40.0
# 3297               FIRE                 F           Salary           40.0
# 3298             POLICE                 F           Salary           40.0
# 3736             POLICE                 F           Salary           40.0
# 3737             POLICE                 F           Salary           40.0
# 3918               FIRE                 F           Salary           40.0
# 3919             POLICE                 F           Salary           40.0
# ...                 ...               ...              ...            ...
# 31298  GENERAL SERVICES                 F           Hourly           40.0
# 31299    PUBLIC LIBRARY                 F           Salary           40.0
# 31310            POLICE                 F           Salary           40.0
# 31311              FIRE                 F           Salary           40.0
# 31412            POLICE                 F           Salary           40.0
# 31413           FINANCE                 F           Salary           40.0
# 31889              FIRE                 F           Salary           40.0
# 31890            POLICE                 F           Salary           40.0
# 31921  FAMILY & SUPPORT                 P           Hourly           20.0
# 31922  FAMILY & SUPPORT                 P           Hourly           20.0
# 31940          AVIATION                 F           Hourly           40.0
# 31941        TRANSPORTN                 F           Hourly           40.0
# 32052   HUMAN RESOURCES                 F           Salary           40.0
# 32053     ANIMAL CONTRL                 F           Salary           40.0
# 32057        TRANSPORTN                 F           Hourly           40.0
# 32058     STREETS & SAN                 F           Hourly           40.0
# 32091  GENERAL SERVICES                 F           Salary           40.0
# 32092  GENERAL SERVICES                 F           Hourly           40.0
# 32114            POLICE                 F           Salary           40.0
# 32115              OEMC                 P           Hourly           20.0
# 32127          AVIATION                 F           Hourly           40.0
# 32128       WATER MGMNT                 F           Salary           40.0
# 32258              FIRE                 F           Salary           40.0
# 32259              FIRE                 F           Salary           40.0
# 32270            POLICE                 F           Salary           40.0
# 32271     STREETS & SAN                 F           Hourly           40.0
# 32280            POLICE                 F           Salary           40.0
# 32281            POLICE                 F           Salary           40.0
# 32672          AVIATION                 P           Hourly           20.0
# 32673              FIRE                 F           Salary           40.0
#
#        annual_salary  hourly_rate   last_name first_name middle_name  \
# 173         84054.00    40.410577         ADE      JAMES           P
# 174        111474.00    53.593269         ADE      JAMES           P
# 735         94824.00    45.588462    ANDERSON      DAVID           C
# 736              NaN    44.880000    ANDERSON      DAVID           C
# 742              NaN    50.250000    ANDERSON     DONALD
# 743         80868.00    38.878846    ANDERSON     DONALD
# 788         43644.00    20.982692    ANDERSON     RHONDA           M
# 789        104628.00    50.301923    ANDERSON     RHONDA           M
# 1051        84516.00    40.632692      ARROYO  FRANCISCO
# 1052        76716.00    36.882692      ARROYO  FRANCISCO
# 1133             NaN    46.350000       ATECA   SALVADOR           R
# 1134             NaN    35.600000       ATECA   SALVADOR           R
# 2148        51264.00    24.646154     BIANCHI    MICHAEL           J
# 2149       112112.04    53.900019     BIANCHI    MICHAEL           J
# 2750             NaN    45.350000     BRACKEN     DANIEL           J
# 2751        76266.00    36.666346     BRACKEN     DANIEL           J
# 3077             NaN    21.430000       BROWN    ANTHONY
# 3078        90024.00    43.280769       BROWN    ANTHONY
# 3130        63876.00    30.709615       BROWN      DIANE
# 3131             NaN    32.040000       BROWN      DIANE
# 3226        48078.00    23.114423       BROWN    MICHAEL
# 3227             NaN    19.860000       BROWN    MICHAEL
# 3244       114324.00    54.963462       BROWN    PATRICK           J
# 3245        97440.00    46.846154       BROWN    PATRICK           J
# 3297       103350.00    49.687500       BROWN    WILLIAM           R
# 3298        98052.00    47.140385       BROWN    WILLIAM           R
# 3736        90024.00    43.280769     CACERES    RICHARD
# 3737        93354.00    44.881731     CACERES    RICHARD
# 3918        95484.00    45.905769    CAMPBELL    MICHAEL           P
# 3919       104628.00    50.301923    CAMPBELL    MICHAEL           P
# ...              ...          ...         ...        ...         ...
# 31298            NaN    23.310000  WASHINGTON    BARBARA           A
# 31299       46152.00    22.188462  WASHINGTON    BARBARA           A
# 31310      170112.00    81.784615  WASHINGTON       ERIC           T
# 31311       80868.00    38.878846  WASHINGTON       ERIC           T
# 31412       72510.00    34.860577      WATSON    WILLIAM
# 31413       83484.00    40.136538      WATSON    WILLIAM
# 31889       95484.00    45.905769    WILLIAMS      ANDRE
# 31890       87006.00    41.829808    WILLIAMS      ANDRE
# 31921            NaN     2.650000    WILLIAMS     BRENDA
# 31922            NaN    13.000000    WILLIAMS     BRENDA
# 31940            NaN    32.040000    WILLIAMS   CLARENCE
# 31941            NaN    35.600000    WILLIAMS   CLARENCE
# 32052       52692.00    25.332692    WILLIAMS   KIMBERLY
# 32053       45696.00    21.969231    WILLIAMS   KIMBERLY
# 32057            NaN    40.200000    WILLIAMS      LARUE
# 32058            NaN    20.770000    WILLIAMS      LARUE
# 32091       60312.00    28.996154    WILLIAMS    MICHAEL
# 32092            NaN    23.310000    WILLIAMS    MICHAEL
# 32114       63876.00    30.709615    WILLIAMS   PATRICIA           A
# 32115            NaN    19.860000    WILLIAMS   PATRICIA           A
# 32127            NaN    15.650000    WILLIAMS     REGINA
# 32128       50100.00    24.086538    WILLIAMS     REGINA
# 32258       91272.00    43.880769      WILSON     EDWARD           J
# 32259       91080.00    43.788462      WILSON     EDWARD           J
# 32270       87006.00    41.829808      WILSON     JANICE           L
# 32271            NaN    36.210000      WILSON     JANICE           L
# 32280       72510.00    34.860577      WILSON     JOSHUA
# 32281       80016.00    38.469231      WILSON     JOSHUA
# 32672            NaN    22.350000   WRONOWSKI      JAMES           J
# 32673       87006.00    41.829808   WRONOWSKI      JAMES           J
#
#        annualized_income
# 173             84054.00
# 174            111474.00
# 735             94824.00
# 736             93350.40
# 742            104520.00
# 743             80868.00
# 788             43644.00
# 789            104628.00
# 1051            84516.00
# 1052            76716.00
# 1133            96408.00
# 1134            74048.00
# 2148            51264.00
# 2149           112112.04
# 2750            94328.00
# 2751            76266.00
# 3077            44574.40
# 3078            90024.00
# 3130            63876.00
# 3131            66643.20
# 3226            48078.00
# 3227            20654.40
# 3244           114324.00
# 3245            97440.00
# 3297           103350.00
# 3298            98052.00
# 3736            90024.00
# 3737            93354.00
# 3918            95484.00
# 3919           104628.00
# ...                  ...
# 31298           48484.80
# 31299           46152.00
# 31310          170112.00
# 31311           80868.00
# 31412           72510.00
# 31413           83484.00
# 31889           95484.00
# 31890           87006.00
# 31921            2756.00
# 31922           13520.00
# 31940           66643.20
# 31941           74048.00
# 32052           52692.00
# 32053           45696.00
# 32057           83616.00
# 32058           43201.60
# 32091           60312.00
# 32092           48484.80
# 32114           63876.00
# 32115           20654.40
# 32127           32552.00
# 32128           50100.00
# 32258           91272.00
# 32259           91080.00
# 32270           87006.00
# 32271           75316.80
# 32280           72510.00
# 32281           80016.00
# 32672           23244.00
# 32673           87006.00
#
# [578 rows x 12 columns]

# %% [markdown]
# ### Data Enrichment: Gender
#
# We'll use the [gender-guesser](https://github.com/lead-ratings/gender-guesser) package to match our first names to a gender. According to the documentation,
#
# > "The result will be one of `unknown` (name not found), `andy` (androgynous), `male`, `female`, `mostly_male`, or `mostly_female`. The difference between `andy` and `unknown` is that the former is found to have the same probability to be male than to be female, while the later means that the name wasn't found in the database.
#
# Let's try it out.

# %%
import gender_guesser.detector as gender

detector = gender.Detector(case_sensitive=False)

# %%
detector.get_gender('Bobby')
# Out:
# 'male'

# %%
detector.get_gender('Sarah')
# Out:
# 'female'

# %%
detector.get_gender('Pat')
# Out:
# 'andy'

# %%
detector.get_gender('Aidin')
# Out:
# 'unknown'

# %%
detector.get_gender('Kelly')
# Out:
# 'mostly_female'

# %%
detector.get_gender('Gene')
# Out:
# 'mostly_male'

# %% [markdown]
# Let's see how this package performs with our list of first names:
